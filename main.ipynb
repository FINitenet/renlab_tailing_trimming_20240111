# %%
# %%bash
#
# python3 /bios-store1/chenyc/scripts/renlab_tailing_trimming_20240111/script/tailing_trmming_preprocess.py -i 1_rawdata/ -o .

# %%
# %%bash
#
# python /bios-store1/chenyc/scripts/renlab_tailing_trimming_20240111/script/tailing_trimming_profile.py -i 3_remapping/ -o .

# %%
# %%bash
#
# 0_workflow_for_srna_seq.py -i 1_rawdata/ -o . -u 2

# %%
# %%bash
#
# /bios-store1/chenyc/scripts/TRMRNAseqTools/module/mapping_results_summary.py  -i . -o . -t 4_mapping

# %%
# %%bash
#
# python /bios-store1/chenyc/scripts/renlab_tailing_trimming_20240111/script/tailing_trimming_length_dist_new.py -i 3_remapping/ -o .

# %%
# %%bash
#
# mkdir -p /bios-store1/chenyc/Project/YHR/Project_yanghuiru_240510N/5_GMC_analysis/doc
# mkdir -p /bios-store1/chenyc/Project/YHR/Project_yanghuiru_240510N/5_GMC_analysis/plot
# mkdir -p /bios-store1/chenyc/Project/YHR/Project_yanghuiru_240510N/5_GMC_analysis/bin
#
#
# list=$(cat /bios-store1/chenyc/Project/YHR/Project_yanghuiru_240510N/filelist)
#
# for i in ${list}
#     do
#         /usr/local/bin/Rscript --vanilla /bios-store1/chenyc/scripts/renlab_tailing_trimming_20240111/script/tailing_trimming_tail_base_summary_mod.R "$i" /bios-store1/chenyc/Project/YHR/Project_yanghuiru_240510N/ /bios-store1/chenyc/Project/YHR/Project_yanghuiru_240510N/mapping_results_bowtie_4_mapping.csv &
#     done
#     wait
#
# printf "tail base summary finished\n"
# Out:
# [1] "processing: 2L_896_240510N_R1"
# [1] "processing: 1F2_576_240510N_R1"
# [1] "processing: 1D2_865_240510N_R1"
# [1] "processing: 2L_14_15_496_240510N_R1"
# [1][1] "processing: hen1_8_240510N_R1"
#  "processing: 1P1_867_240510N_R1"
# [1] "processing: 2F_4_4138_240510N_R1"
# tail base summary finished
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ...
